# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/mtcd/Library/Mobile Documents/com~apple~CloudDocs/@Pessoal/@Evernote/Estudos/@programming/p.qualidade_ar_work/dataset/SP/SP202001.csv', encoding='ISO-8859-1')

df = df.loc[ (df['Estacao'] == 'Mooca') & (df['Poluente'] == 'O3') & (df['Data'] == '2020-01-05') ]

df
# Out:
#               Data   Hora Estacao Codigo Poluente  Valor Unidade        Tipo
# 742520  2020-01-05  01:00   Mooca   SP40       O3   32.0   ug/m3  automatica
# 742521  2020-01-05  02:00   Mooca   SP40       O3   29.0   ug/m3  automatica
# 742522  2020-01-05  03:00   Mooca   SP40       O3   24.0   ug/m3  automatica
# 742523  2020-01-05  04:00   Mooca   SP40       O3   29.0   ug/m3  automatica
# 742524  2020-01-05  05:00   Mooca   SP40       O3   23.0   ug/m3  automatica
# 742525  2020-01-05  06:00   Mooca   SP40       O3   18.0   ug/m3  automatica
# 742526  2020-01-05  07:00   Mooca   SP40       O3   19.0   ug/m3  automatica
# 742527  2020-01-05  08:00   Mooca   SP40       O3   25.0   ug/m3  automatica
# 742528  2020-01-05  09:00   Mooca   SP40       O3   29.0   ug/m3  automatica
# 742529  2020-01-05  10:00   Mooca   SP40       O3   41.0   ug/m3  automatica
# 742530  2020-01-05  11:00   Mooca   SP40       O3   52.0   ug/m3  automatica
# ...
