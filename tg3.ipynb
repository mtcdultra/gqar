# %%
poluente_ec_urban_off_peak  = {'Frota atual': 0.2348, 'Gasolina': 0.2740, 'Hibrido': 0.1548}
poluente_ec_urban_peak      = {'Frota atual': 3.1350, 'Gasolina': 3.6896, 'Hibrido': 1.8869}
poluente_ec_rural           = {'Frota atual': 0.1949, 'Gasolina': 0.2202, 'Hibrido': 0.1197}
poluente_ec_highway         = {'Frota atual': 1.1785, 'Gasolina': 1.2786, 'Hibrido': 0.8959}

poluente_co_urban_off_peak  = {'Frota atual': 0.0645, 'Gasolina': 0.1393, 'Hibrido': 0.1233}
poluente_co_urban_peak      = {'Frota atual': 0.7783, 'Gasolina': 1.6763, 'Hibrido': 1.4994}
poluente_co_rural           = {'Frota atual': 0.0096, 'Gasolina': 0.0197, 'Hibrido': 0.0031}
poluente_co_highway         = {'Frota atual': 0.0932, 'Gasolina': 0.1986, 'Hibrido': 0.0083}

poluente_co2_urban_off_peak  = {'Frota atual': 17.1818,  'Gasolina': 19.7128,  'Hibrido': 11.1054}
poluente_co2_urban_peak      = {'Frota atual': 229.7786, 'Gasolina': 266.2940, 'Hibrido': 136.1511}
poluente_co2_rural           = {'Frota atual': 14.2909,  'Gasolina': 15.8739,  'Hibrido': 8.6219}
poluente_co2_highway         = {'Frota atual': 86.4440,  'Gasolina': 92.2893,  'Hibrido': 64.6539}

poluente_voc_urban_off_peak  = {'Frota atual': 0.0207, 'Gasolina': 0.0689, 'Hibrido': 0.0068}
poluente_voc_urban_peak      = {'Frota atual': 0.2725, 'Gasolina': 0.6056, 'Hibrido': 0.5995}
poluente_voc_rural           = {'Frota atual': 0.0028, 'Gasolina': 0.0055, 'Hibrido': 0.0052}
poluente_voc_highway         = {'Frota atual': 0.0043, 'Gasolina': 0.0086, 'Hibrido': 0.0055}

# %%
print(poluente_ec_urban_off_peak)
# Out:
# {'Frota atual': 0.2348, 'Gasolina': 0.274, 'Hibrido': 0.1548}

# %%
import numpy as np
import matplotlib.pyplot as plt

data        = list(poluente_ec_urban_off_peak.keys())
values1     = list(poluente_ec_urban_off_peak.values())
values2     = list(poluente_ec_urban_peak.values())
values3     = list(poluente_ec_rural.values())
values4     = list(poluente_ec_highway.values())

x = np.arange(len(data))
width = 0.2
fig, ax = plt.subplots()
rects1 = ax.bar( x - 0.4, values1, width, label='Urban off peak')
rects2 = ax.bar( x - 0.2, values2, width, label='Urban Peak')
rects3 = ax.bar( x, values3, width, label='Rurak')
rects4 = ax.bar( x + 0.2, values4, width, label='Highway')

ax.set_ylabel('TJ/km')
ax.set_title('Energy Consumption')
ax.set_xticks(x, data)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.bar_label(rects4, padding=3)

plt.show*()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/mtcd/Library/Mobile Documents/com~apple~CloudDocs/@Pessoal/@Evernote/Estudos/@programming/p.qualidade_ar_work/tg3.ipynb Cell 3 in <cell line: 28>()
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#W4sZmlsZQ%3D%3D?line=24'>25</a> ax.bar_label(rects3, padding=3)
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#W4sZmlsZQ%3D%3D?line=25'>26</a> ax.bar_label(rects4, padding=3)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

data        = list(poluente_co_urban_off_peak.keys())
values1     = list(poluente_co_urban_off_peak.values())
values2     = list(poluente_co_urban_peak.values())
values3     = list(poluente_co_rural.values())
values4     = list(poluente_co_highway.values())

x = np.arange(len(data))
width = 0.2
fig, ax = plt.subplots()
rects1 = ax.bar( x - 0.4, values1, width, label='Urban off peak')
rects2 = ax.bar( x - 0.2, values2, width, label='Urban Peak')
rects3 = ax.bar( x, values3, width, label='Real')
rects4 = ax.bar( x + 0.2, values4, width, label='Highway')

ax.set_ylabel('T')
ax.set_title('CO consumption')
ax.set_xticks(x, data)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.bar_label(rects4, padding=3)

plt.show*()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/mtcd/Library/Mobile Documents/com~apple~CloudDocs/@Pessoal/@Evernote/Estudos/@programming/p.qualidade_ar_work/tg3.ipynb Cell 4 in <cell line: 28>()
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#W5sZmlsZQ%3D%3D?line=24'>25</a> ax.bar_label(rects3, padding=3)
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#W5sZmlsZQ%3D%3D?line=25'>26</a> ax.bar_label(rects4, padding=3)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

data        = list(poluente_co2_urban_off_peak.keys())
values1     = list(poluente_co2_urban_off_peak.values())
values2     = list(poluente_co2_urban_peak.values())
values3     = list(poluente_co2_rural.values())
values4     = list(poluente_co2_highway.values())

x = np.arange(len(data))
width = 0.2
fig, ax = plt.subplots()
rects1 = ax.bar( x - 0.4, values1, width, label='Urban off peak')
rects2 = ax.bar( x - 0.2, values2, width, label='Urban Peak')
rects3 = ax.bar( x, values3, width, label='Rurak')
rects4 = ax.bar( x + 0.2, values4, width, label='Highway')

ax.set_ylabel('T')
ax.set_title('Poluente CO2')
ax.set_xticks(x, data)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.bar_label(rects4, padding=3)

plt.show*()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/mtcd/Library/Mobile Documents/com~apple~CloudDocs/@Pessoal/@Evernote/Estudos/@programming/p.qualidade_ar_work/tg3.ipynb Cell 5 in <cell line: 29>()
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#W6sZmlsZQ%3D%3D?line=25'>26</a> ax.bar_label(rects3, padding=3)
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#W6sZmlsZQ%3D%3D?line=26'>27</a> ax.bar_label(rects4, padding=3)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

data        = list(poluente_voc_urban_off_peak.keys())
values1     = list(poluente_voc_urban_off_peak.values())
values2     = list(poluente_voc_urban_peak.values())
values3     = list(poluente_voc_rural.values())
values4     = list(poluente_voc_highway.values())

x = np.arange(len(data))
width = 0.2
fig, ax = plt.subplots()
rects1 = ax.bar( x - 0.4, values1, width, label='Urban off peak')
rects2 = ax.bar( x - 0.2, values2, width, label='Urban Peak')
rects3 = ax.bar( x, values3, width, label='Rurak')
rects4 = ax.bar( x + 0.2, values4, width, label='Highway')

ax.set_ylabel('T')
ax.set_title('Poluente VOC')
ax.set_xticks(x, data)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.bar_label(rects4, padding=3)

plt.show*()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/mtcd/Library/Mobile Documents/com~apple~CloudDocs/@Pessoal/@Evernote/Estudos/@programming/p.qualidade_ar_work/tg3.ipynb Cell 6 in <cell line: 30>()
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X10sZmlsZQ%3D%3D?line=26'>27</a> ax.bar_label(rects3, padding=3)
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X10sZmlsZQ%3D%3D?line=27'>28</a> ax.bar_label(rects4, padding=3)
# ...

# %%
frota_atual_urban_off_peak = {'ec': 0.2348, 'co2': 0.0645 }
gasolina_urban_off_peak = {'ec': 0.2740, 'co2': 0.1393 }


co = {'frota_atual_co': 17.1818, 'gasolina_co' : 19.7128, 'hibrido_co': 11.1054}
co2 = {'frota_atual_co2': 17.1818, 'gasolina_co2' : 19.7128, 'hibrido_co2': 11.1054}

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))


data        = np.array(list(poluente_ec_urban_off_peak.keys()))
values1     = np.array(list(poluente_co2_urban_off_peak.values()))


#poluentes = ['ec', 'co', 'co2', 'voc']

plt.bar(data, values1, color='gold')

#plt.xlabel('ug/m3')
plt.ylabel('ug/m3')
plt.title('Urban Off Peak')
#plt.legend(poluentes)

plt.show*()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/mtcd/Library/Mobile Documents/com~apple~CloudDocs/@Pessoal/@Evernote/Estudos/@programming/p.qualidade_ar_work/tg3.ipynb Cell 9 in <cell line: 20>()
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X13sZmlsZQ%3D%3D?line=16'>17</a> plt.title('Urban Off Peak')
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X13sZmlsZQ%3D%3D?line=17'>18</a> #plt.legend(poluentes)
# ---> <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X13sZmlsZQ%3D%3D?line=19'>20</a> plt.show*()
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))


data        = np.array(list(poluente_co_urban_peak.keys()))
values1     = np.array(list(poluente_co_urban_peak.values()))
values2     = np.array(list(poluente_co2_urban_peak.values()))
values3     = np.array(list(poluente_voc_urban_peak.values()))


poluentes = ['co', 'co2', 'voc']

plt.bar(data, values1, color='red')
plt.bar(data, values2, color='gray', bottom = values1)
plt.bar(data, values3, color='orange', bottom = values1 + values2)

plt.ylabel('ug/m3')
plt.title('Urban Peak')
plt.legend(poluentes)

plt.show*()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/mtcd/Library/Mobile Documents/com~apple~CloudDocs/@Pessoal/@Evernote/Estudos/@programming/p.qualidade_ar_work/tg3.ipynb Cell 10 in <cell line: 23>()
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X14sZmlsZQ%3D%3D?line=19'>20</a> plt.title('Urban Peak')
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X14sZmlsZQ%3D%3D?line=20'>21</a> plt.legend(poluentes)
# ---> <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X14sZmlsZQ%3D%3D?line=22'>23</a> plt.show*()
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))


data        = np.array(list(poluente_ec_urban_peak.keys()))
values1     = np.array(list(poluente_ec_urban_peak.values()))
values2     = np.array(list(poluente_co_urban_peak.values()))
values3     = np.array(list(poluente_voc_urban_peak.values()))

poluentes = ['EC', 'CO', 'VOC']

plt.bar(data, values1, color='gold')
plt.bar(data, values2, color='gray', bottom = values1)
plt.bar(data, values3, color='orange', bottom = values1 + values2)

#plt.xlabel('ug/m3')
plt.ylabel('ug/m3')
plt.title('Urban Off Peak')
plt.legend(poluentes)

plt.show*()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/mtcd/Library/Mobile Documents/com~apple~CloudDocs/@Pessoal/@Evernote/Estudos/@programming/p.qualidade_ar_work/tg3.ipynb Cell 11 in <cell line: 23>()
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X15sZmlsZQ%3D%3D?line=19'>20</a> plt.title('Urban Off Peak')
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X15sZmlsZQ%3D%3D?line=20'>21</a> plt.legend(poluentes)
# ---> <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X15sZmlsZQ%3D%3D?line=22'>23</a> plt.show*()
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))


data        = np.array(list(poluente_ec_rural.keys()))
values1     = np.array(list(poluente_ec_rural.values()))
values2     = np.array(list(poluente_co_rural.values()))
values3     = np.array(list(poluente_voc_rural.values()))

poluentes = ['EC', 'CO', 'VOC']

plt.bar(data, values1, color='gold')
plt.bar(data, values2, color='gray', bottom = values1)
plt.bar(data, values3, color='orange', bottom = values1 + values2)

#plt.xlabel('ug/m3')
plt.ylabel('ug/m3')
plt.title('Highway')
plt.legend(poluentes)

plt.show*()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/mtcd/Library/Mobile Documents/com~apple~CloudDocs/@Pessoal/@Evernote/Estudos/@programming/p.qualidade_ar_work/tg3.ipynb Cell 12 in <cell line: 23>()
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X21sZmlsZQ%3D%3D?line=19'>20</a> plt.title('Highway')
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X21sZmlsZQ%3D%3D?line=20'>21</a> plt.legend(poluentes)
# ---> <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X21sZmlsZQ%3D%3D?line=22'>23</a> plt.show*()
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))


data        = np.array(list(poluente_ec_highway.keys()))
values1     = np.array(list(poluente_ec_highway.values()))
values2     = np.array(list(poluente_co_highway.values()))
values3     = np.array(list(poluente_voc_highway.values()))

poluentes = ['EC', 'CO', 'VOC']

plt.bar(data, values1, color='gold')
plt.bar(data, values2, color='gray', bottom = values1)
plt.bar(data, values3, color='orange', bottom = values1 + values2)

#plt.xlabel('ug/m3')
plt.ylabel('ug/m3')
plt.title('Highway')
plt.legend(poluentes)

plt.show*()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/mtcd/Library/Mobile Documents/com~apple~CloudDocs/@Pessoal/@Evernote/Estudos/@programming/p.qualidade_ar_work/tg3.ipynb Cell 12 in <cell line: 23>()
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X16sZmlsZQ%3D%3D?line=19'>20</a> plt.title('Urban Off Peak')
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X16sZmlsZQ%3D%3D?line=20'>21</a> plt.legend(poluentes)
# ---> <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X16sZmlsZQ%3D%3D?line=22'>23</a> plt.show*()
#
# ...

# %%
#poluente_ec_urban_off_peak  = {'Frota atual': 0.2348, 'Gasolina': 0.2740, 'Hibrido': 0.1548}
#poluente_ec_urban_peak      = {'Frota atual': 3.1350, 'Gasolina': 3.6896, 'Hibrido': 1.8869}
#poluente_ec_rural           = {'Frota atual': 0.1949, 'Gasolina': 0.2202, 'Hibrido': 0.1197}
#poluente_ec_highway         = {'Frota atual': 1.1785, 'Gasolina': 1.2786, 'Hibrido': 0.8959}

#poluente_co_urban_off_peak  = {'Frota atual': 0.0645, 'Gasolina': 0.1393, 'Hibrido': 0.1233}
#p#oluente_co_urban_peak      = {'Frota atual': 0.7783, 'Gasolina': 1.6763, 'Hibrido': 1.4994}
#poluente_co_rural           = {'Frota atual': 0.0096, 'Gasolina': 0.0197, 'Hibrido': 0.0031}
#poluente_co_highway         = {'Frota atual': 0.0932, 'Gasolina': 0.1986, 'Hibrido': 0.0083}

#poluente_co2_urban_off_peak  = {'Frota atual': 17.1818,  'Gasolina': 19.7128,  'Hibrido': 11.1054}
#poluente_co2_urban_peak      = {'Frota atual': 229.7786, 'Gasolina': 266.2940, 'Hibrido': 136.1511}
#poluente_co2_rural           = {'Frota atual': 14.2909,  'Gasolina': 15.8739,  'Hibrido': 8.6219}
#poluente_co2_highway         = {'Frota atual': 86.4440,  'Gasolina': 92.2893,  'Hibrido': 64.6539}

#poluente_voc_urban_off_peak  = {'Frota atual': 0.0207, 'Gasolina': 0.0689, 'Hibrido': 0.0068}
#p#oluente_voc_urban_peak      = {'Frota atual': 0.2725, 'Gasolina': 0.6056, 'Hibrido': 0.5995}
#poluente_voc_rural           = {'Frota atual': 0.0028, 'Gasolina': 0.0055, 'Hibrido': 0.0052}
#poluente_voc_highway         = {'Frota atual': 0.0043, 'Gasolina': 0.0086, 'Hibrido': 0.0055}

import numpy as np
import matplotlib.pyplot as plt

data        = list(poluente_ec_urban_off_peak.keys())
values1     = list(poluente_ec_urban_off_peak.values())
values2     = list(poluente_co_urban_off_peak.values())
values3     = list(poluente_co2_urban_off_peak.values())


x = np.arange(len(data))
width = 0.2
fig, ax = plt.subplots()
rects1 = ax.bar( x - 0.4, values1, width, label='ec')
rects2 = ax.bar( x - 0.2, values2, width, label='Urban Peak')
rects3 = ax.bar( x, values3, width, label='Rurak')


ax.set_ylabel('TJ/km')
ax.set_title('Energy Consumption')
ax.set_xticks(x, data)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)



plt.show*()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/mtcd/Library/Mobile Documents/com~apple~CloudDocs/@Pessoal/@Evernote/Estudos/@programming/p.qualidade_ar_work/tg3.ipynb Cell 14 in <cell line: 49>()
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X22sZmlsZQ%3D%3D?line=43'>44</a> ax.bar_label(rects2, padding=3)
#      <a href='vscode-notebook-cell:/Users/mtcd/Library/Mobile%20Documents/com~apple~CloudDocs/%40Pessoal/%40Evernote/Estudos/%40programming/p.qualidade_ar_work/tg3.ipynb#X22sZmlsZQ%3D%3D?line=44'>45</a> ax.bar_label(rects3, padding=3)
# ...
